# %% [markdown]
# **Question 1:** A die is rolled. What is the probability of getting:
#
# (a) An even number
#
# (b) A number greater than 4
#
# **Answer-**
#
# * Even Number = 3/6
#
# * A Number Greater than 4 = 2/6

# %% [markdown]
# **Question 2:** In a class of 50 students:
#
# 20 like Mathematics (M)
#
# 15 like Science (S)
#
# 5 like both subjects
#
# What is the probability that a student chosen at random likes Mathematics or Science?
#
# **Anwer -** 20 + 15 -5/50
#
#
# Probability of student who chosen at random subject is
#
# = 30/50
#
# = zero zero cancel so 3/5
#
#
# also (0.6)

# %% [markdown]
# **Question 3:** A bag has 3 red and 2 blue balls. If one ball is drawn randomly and is red, what is the probability
# that the next ball is also red (without replacement)?
#
# **Answer-** if a bag has 3 red or 2 blue then total number of ball is 5
#
# after ball drawn randomly a red ball  number off ball remaning is 4
#
# probablity is
# = 2/4
#
# = 0.5

# %% [markdown]
# **Question 4:** The population of a school is divided into 60% boys and 40% girls. If you want equal representation
# of both genders in the sample, which method should you use: Simple Random Sampling or Stratified Sampling?
# Why?
#
# **Answer-** Using Simple Random Sampling bacause From the population we have to take equal number of boy and girls and random samplling gather the equal number form the populatio.italicised text

# %% [markdown]
# **Question 5:** The average height of 1000 students = 160 cm. A sample of 100 students shows an average height
# = 158 cm.
#
# Find the sampling error.
#
# **Answer-** population mean is 160cm
#
# Sample mean is 158cm
#
# 160-158 = 2cm
#
# Sampling error is *2cm*

# %% [markdown]
# **Question 6:** The population mean salary is ₹50,000 with σ = ₹5,000. If we take a sample of 100 employees, what
# is the standard error of the mean (SEM)?
#
#
# **Answer-**
#
# σ = ₹5,000.
#
# n = 100
#
# SEM= σ/√n
#
# = 5000/√100
#
# = 5000/10
#
# SEM =₹500

# %% [markdown]
# **Question 7:** In a group of 100 students:
#
# 40 like Cricket (C)
#
# 30 like Football (F)
#
# 10 like both Cricket and Football
#
# Find the probability that a student likes at least one sport.
#
# **Answer-** 40 like crickat
# 30 like football
#  10 like both
#  then
#
#  40+30-10= 60
#
# = 60/100
#
#  = 6/10
#
#  =0.6

# %% [markdown]
# **Question 8:** From a deck of 52 cards, two cards are drawn without replacement. What is the probability that
# both are Aces?
#
# **Answer-**  total card = 51
#
# total ace = 4
#
# fisrt time = 4/51
#
# second time = 3/51
#
# probabilty of both ace = 4/51 * 3/51
#
# = 12/2652
#
# =1/221

# %% [markdown]
# **Question 9:** A factory produces bulbs with 2% defective rate. If 5 bulbs are chosen at random, what is the
# probability that all are non-defective?
#
# **Answer-** if 2% defective rate then 100-2
#
# = 98%
#
# = 0.98
#
# = (0.98)*5
#
# = 0.9039
#
# = 90%

# %% [markdown]
# **Question 10:** Differentiate between discrete and continuous random variables with examples
#
# # **Answer-**  Discrite Random variable
#
# The variable which are in whole number and countable these are Discrite Random variable
#
# example: Number of student in class
#
# count of car in showroom
#
# # **continuous random variables**
#
# the variable which are in form of range not fix number that is continuous random variables
#
# Example: Hight of a person
#
# temparture of any city or area
